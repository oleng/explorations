# %% [markdown]
# ## Overview
#
# pandas is a very useful tool for manipulating data, but it's heavy on memory resource due to the amount of features it provides. People (ab)use pandas out of convenience for opening big CSV, Excel & other file formats, which is fine for most part, but sometimes using pandas just to take a look & manipulating a little bit of big data file is slow & cumbersome. So I'm going to use python generator to demonstrate it doesn't take much to achieve this kind of task with built-in modules, although I suspect it _might be_ more expensive on I/O side, but speed wise this is faster because this one only lazily loads the data when you need it.
#
# I'm going to use this bank dataset from data.gov: https://catalog.data.gov/dataset/development-credit-authority-dca-data-set-loan-transactions-28508 renamed as `'credit_loan_dataset.csv'`. It's ~33MB of comma delimited CSV, containing 186,545 rows of raw data.
#
# ### Software & hardwares
#
# This is based on miniconda IPython version 7.9.0 (Python 3.7.5) in macOS Mojave 10.14.6 with 16GB of 2133MHz memory chip and a cheap 120GB whitebranded **SATA** M.2 drive. YMMV on the actual performance on your machine, but regular SATA SSD should be comparable & PCIe NVMe M.2 is much faster.

# %%
import json, csv
from pprint import pprint

def open_csv(filename, stop=5, dialect='excel'):
        
    with open(filename, 'r') as f:
        reader = csv.DictReader(f, dialect=dialect)
        for i in range(0, 1, stop):
            for row in reader:
                yield row

# %%
# let's try and see if this works
# in python v.3.8 the output of `csv.DictWriter` is a `dict`, but v3 prior to 3.8 it's `OrderedDict`
data = open_csv('credit_loan_dataset.csv')
test = dict(next(data))

# %%
test
# Out:
# {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#  'Transaction Report ID': '356191',
#  'Guarantee Country Name': 'Worldwide',
#  'Amount (USD)': '980144.4043',
#  'Currency Name': 'PERU - NUEVO SOL',
#  'Disbursement Date': '09/20/2011 12:00:00 AM',
#  'End Date': '09/09/2013 12:00:00 AM',
#  'Business Sector': '',
#  'City/Town': 'Cusco',
#  'State/Province/Region Name': 'Cusco',
#  'State/Province/Region Code': 'PE08',
#  'State/Province/Region Country Name': 'Peru',
#  'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#  'Is Woman Owned?': '0',
#  'Is First Time Borrower?': '1',
#  'Business Size': '>100',
#  'Latitude': '-13.518333',
#  'Longitude': '-71.978056'}

# %%
# again
test
# Out:
# {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#  'Transaction Report ID': '356191',
#  'Guarantee Country Name': 'Worldwide',
#  'Amount (USD)': '980144.4043',
#  'Currency Name': 'PERU - NUEVO SOL',
#  'Disbursement Date': '09/20/2011 12:00:00 AM',
#  'End Date': '09/09/2013 12:00:00 AM',
#  'Business Sector': '',
#  'City/Town': 'Cusco',
#  'State/Province/Region Name': 'Cusco',
#  'State/Province/Region Code': 'PE08',
#  'State/Province/Region Country Name': 'Peru',
#  'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#  'Is Woman Owned?': '0',
#  'Is First Time Borrower?': '1',
#  'Business Size': '>100',
#  'Latitude': '-13.518333',
#  'Longitude': '-71.978056'}

# %%
# lets see if this works
test2 = [dict(next(data))]*5

# %%
test2
# Out:
# [{'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Transaction Report ID': '331620',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1960288.809',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': 'Puno',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '-15',
#   'Longitude': '-70'},
#  {'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Transaction Report ID': '331620',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1960288.809',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': 'Puno',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '-15',
#   'Longitude': '-70'},
#  {'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Transaction Report ID': '331620',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1960288.809',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': 'Puno',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '-15',
#   'Longitude': '-70'},
#  {'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Transaction Report ID': '331620',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1960288.809',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': 'Puno',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '-15',
#   'Longitude': '-70'},
#  {'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Transaction Report ID': '331620',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1960288.809',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': 'Puno',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '-15',
#   'Longitude': '-70'}]

# %%
len(test2)
# Out:
# 5

# %%
# %lsmagic # this is a list of ipython features that you can use in Jupyter notebooks
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# some useful links for `%magic`:
#
# * https://ipython.readthedocs.io/en/stable/interactive/tutorial.html#magic-functions
# * https://stackoverflow.com/questions/49136737/how-profiling-class-method-using-ipython-lprun-magic-function

# %% [markdown]
# to install external profiler on conda use `conda install line_profiler` if you're using conda/miniconda, or follow guide in https://github.com/rkern/line_profiler#installation
# memory_profiler is available on conda & can be installed with `pip install memory_profiler`
#
# Make sure your in the right virtual env.

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
import json, csv
from pprint import pprint

def open_csv(filename, stop=5, dialect='excel'):
        
    with open(filename, 'r') as f:
        reader = csv.DictReader(f, dialect=dialect)
        for i in range(0, 1):
            for row in reader:
                yield row
    

def get_csv_rows(filename, stop):
    data = open_csv(filename, stop)
    return [dict(next(data))] * stop

# %%
# %timeit get_csv_rows('credit_loan_dataset.csv', 10)
# Out:
# 52.5 µs ± 3.99 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %lprun get_csv_rows('credit_loan_dataset.csv', 10)

# %%
# %mprun get_csv_rows('credit_loan_dataset.csv', 10)

# %%
# %%time
get_csv_rows('credit_loan_dataset.csv', 10)
# Out:
# CPU times: user 395 µs, sys: 344 µs, total: 739 µs
# Wall time: 482 µs
# [{'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'}]

# %%
# %%time
get_csv_rows('credit_loan_dataset.csv', 1000)
# Out:
# CPU times: user 366 µs, sys: 283 µs, total: 649 µs
# Wall time: 448 µs
# [{'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
# ...
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'}]

# %%
# !python -m line_profiler profile.lprof chunk_csv.py
# Out:
# /usr/local/Caskroom/miniconda/base/envs/notebooks/bin/python: No module named line_profiler

# %%
# !python -m cProfile -s cumtime chunk_csv.py
# Out:
#          3809 function calls (3691 primitive calls) in 0.007 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       7/1    0.000    0.000    0.007    0.007 {built-in method builtins.exec}
#         1    0.000    0.000    0.007    0.007 chunk_csv.py:1(<module>)
#       8/3    0.000    0.000    0.007    0.002 <frozen importlib._bootstrap>:978(_find_and_load)
#       8/3    0.000    0.000    0.007    0.002 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#       8/3    0.000    0.000    0.006    0.002 <frozen importlib._bootstrap>:663(_load_unlocked)
#       6/3    0.000    0.000    0.006    0.002 <frozen importlib._bootstrap_external>:722(exec_module)
#      11/3    0.000    0.000    0.005    0.002 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#         1    0.000    0.000    0.004    0.004 __init__.py:97(<module>)
#         1    0.000    0.000    0.003    0.003 decoder.py:2(<module>)
#     15/14    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         1    0.000    0.000    0.003    0.003 {built-in method builtins.__import__}
#         1    0.000    0.000    0.002    0.002 scanner.py:2(<module>)
#         6    0.000    0.000    0.002    0.000 re.py:232(compile)
#         6    0.000    0.000    0.002    0.000 re.py:271(_compile)
#         6    0.000    0.000    0.001    0.000 sre_compile.py:759(compile)
#         6    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:793(get_code)
#         8    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#         8    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#         8    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#         8    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:576(module_from_spec)
#        20    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1040(create_module)
#         2    0.001    0.000    0.001    0.000 {built-in method _imp.create_dynamic}
#         6    0.000    0.000    0.001    0.000 sre_parse.py:913(parse)
#         1    0.000    0.000    0.001    0.001 csv.py:4(<module>)
#      13/6    0.000    0.000    0.001    0.000 sre_parse.py:411(_parse_sub)
#      15/6    0.000    0.000    0.001    0.000 sre_parse.py:469(_parse)
#         6    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:523(_compile_bytecode)
#         6    0.001    0.000    0.001    0.000 {built-in method marshal.loads}
#         6    0.000    0.000    0.001    0.000 sre_compile.py:598(_code)
#        38    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#         1    0.000    0.000    0.000    0.000 encoder.py:2(<module>)
#        38    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#      25/6    0.000    0.000    0.000    0.000 sre_compile.py:71(_compile)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:914(get_data)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#         4    0.000    0.000    0.000    0.000 enum.py:830(__or__)
#        20    0.000    0.000    0.000    0.000 enum.py:284(__call__)
#        20    0.000    0.000    0.000    0.000 enum.py:526(__new__)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:93(_path_isfile)
#         2    0.000    0.000    0.000    0.000 enum.py:793(_missing_)
#         2    0.000    0.000    0.000    0.000 enum.py:800(_create_pseudo_member_)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_path_is_mode_type)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#        25    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#         2    0.000    0.000    0.000    0.000 enum.py:872(_decompose)
#        99    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#        14    0.000    0.000    0.000    0.000 sre_compile.py:276(_optimize_charset)
#         6    0.000    0.000    0.000    0.000 {method 'read' of '_io.FileIO' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         2    0.000    0.000    0.000    0.000 enum.py:890(<listcomp>)
#         6    0.000    0.000    0.000    0.000 sre_compile.py:536(_compile_info)
#        14    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:403(cached)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:951(path_stats)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:271(cache_from_source)
#        71    0.000    0.000    0.000    0.000 sre_parse.py:254(get)
#       123    0.000    0.000    0.000    0.000 sre_parse.py:164(__getitem__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1351(_get_spec)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:369(_get_cached)
#        99    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#     31/12    0.000    0.000    0.000    0.000 sre_parse.py:174(getwidth)
#       102    0.000    0.000    0.000    0.000 sre_parse.py:233(__next)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1190(_path_hooks)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:96(closegroup)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1404(_fill_cache)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#   319/291    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       206    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:574(spec_from_file_location)
#         1    0.000    0.000    0.000    0.000 pprint.py:35(<module>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1445(path_hook_for_FileFinder)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.listdir}
#         6    0.000    0.000    0.000    0.000 enum.py:836(__and__)
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         5    0.000    0.000    0.000    0.000 enum.py:907(_power_of_two)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:103(release)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:318(__exit__)
#        28    0.000    0.000    0.000    0.000 types.py:164(__get__)
#         9    0.000    0.000    0.000    0.000 sre_compile.py:423(_simple)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#       111    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        53    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1319(__init__)
#        16    0.000    0.000    0.000    0.000 sre_parse.py:295(_class_escape)
#       106    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#        14    0.000    0.000    0.000    0.000 sre_compile.py:249(_compile_charset)
#       312    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:78(acquire)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:438(_classify_pyc)
#         4    0.000    0.000    0.000    0.000 sre_compile.py:411(_mk_bitmap)
#        71    0.000    0.000    0.000    0.000 sre_parse.py:249(match)
#        33    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 sre_parse.py:408(_uniq)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:401(_check_name_wrapper)
#       210    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 sre_compile.py:65(_combine_flags)
#        24    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#       8/5    0.000    0.000    0.000    0.000 sre_compile.py:461(_get_literal_prefix)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:224(__init__)
#        38    0.000    0.000    0.000    0.000 sre_parse.py:286(tell)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:62(_path_split)
#         1    0.000    0.000    0.000    0.000 pprint.py:98(PrettyPrinter)
#        62    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#        52    0.000    0.000    0.000    0.000 sre_parse.py:160(__len__)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         6    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:471(_validate_timestamp_pyc)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:84(opengroup)
#         3    0.000    0.000    0.000    0.000 {built-in method _csv.register_dialect}
#         4    0.000    0.000    0.000    0.000 sre_compile.py:413(<listcomp>)
#        59    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#        24    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:859(__exit__)
#        48    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:51(_r_long)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#        44    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1048(exec_module)
#         5    0.000    0.000    0.000    0.000 sre_compile.py:492(_get_charset_prefix)
#        34    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        24    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#        26    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 decoder.py:284(__init__)
#        42    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#        20    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#        12    0.000    0.000    0.000    0.000 sre_compile.py:595(isstring)
#        10    0.000    0.000    0.000    0.000 sre_parse.py:168(__setitem__)
#        25    0.000    0.000    0.000    0.000 sre_parse.py:172(append)
#        10    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        42    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        20    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         4    0.000    0.000    0.000    0.000 sre_parse.py:258(getwhile)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:343(_escape)
#        12    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        18    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         8    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:98(_path_isdir)
#        23    0.000    0.000    0.000    0.000 enum.py:623(name)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:897(fix_flags)
#         2    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#        16    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         5    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#        20    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#         3    0.000    0.000    0.000    0.000 enum.py:855(_high_bit)
#         1    0.000    0.000    0.000    0.000 decoder.py:254(JSONDecoder)
#        32    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         1    0.000    0.000    0.000    0.000 csv.py:81(DictReader)
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1433(<setcomp>)
#        13    0.000    0.000    0.000    0.000 sre_compile.py:453(_get_iscased)
#         8    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10686e568}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:719(create_module)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:884(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1029(__init__)
#         5    0.000    0.000    0.000    0.000 enum.py:628(value)
#         1    0.000    0.000    0.000    0.000 encoder.py:104(__init__)
#         1    0.000    0.000    0.000    0.000 encoder.py:73(JSONEncoder)
#         1    0.000    0.000    0.000    0.000 csv.py:24(Dialect)
#         4    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         3    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         6    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.exec_dynamic}
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1325(<genexpr>)
#         5    0.000    0.000    0.000    0.000 enum.py:901(<lambda>)
#         1    0.000    0.000    0.000    0.000 decoder.py:20(JSONDecodeError)
#         1    0.000    0.000    0.000    0.000 csv.py:55(excel)
#         1    0.000    0.000    0.000    0.000 csv.py:131(DictWriter)
#         1    0.000    0.000    0.000    0.000 csv.py:166(Sniffer)
#         1    0.000    0.000    0.000    0.000 pprint.py:72(_safe_key)
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:909(get_filename)
#         1    0.000    0.000    0.000    0.000 chunk_csv.py:17(open_csv)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 csv.py:65(excel_tab)
#         1    0.000    0.000    0.000    0.000 csv.py:70(unix_dialect)
