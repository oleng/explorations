# %% [markdown]
# ## Overview
#
# pandas is a very useful tool for manipulating data, but it's heavy on memory resource due to the amount of features it provides. People (ab)use pandas out of convenience for opening big CSV, Excel & other file formats, which is fine for most part, but sometimes using pandas just to take a look & manipulating a little bit of big data file is slow & cumbersome. If this is relevant to you but you need to use pandas then you need to use `chunksize` parameter for [`pd.read_csv`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
#
# I'm going to use python generator to demonstrate how to achieve this kind of task with built-in modules, although I suspect it _might be_ more expensive on I/O side, but speed wise this is should be faster because this one only lazily loads the data when you need it without too many dependencies.
#
# I'm going to use this bank dataset from data.gov: https://catalog.data.gov/dataset/development-credit-authority-dca-data-set-loan-transactions-28508 renamed as `'credit_loan_dataset.csv'`. It's ~33MB of comma delimited CSV, containing 186,545 rows of raw data.
#
# ### Software & hardwares
#
# This is based on miniconda IPython version 7.9.0 (Python 3.7.5) in macOS Mojave 10.14.6 with 16GB of 2133MHz memory chip and a cheap 120GB whitebranded **SATA** M.2 drive. YMMV on the actual performance on your machine, but regular SATA SSD should be comparable & PCIe NVMe M.2 is much faster.

# %%
import json, csv
from pprint import pprint

def open_csv(filename, dialect='excel'):
        
    with open(filename, 'r') as f:
        reader = csv.DictReader(f, dialect=dialect)
        for row in reader:
            yield row

# %%
# let's try and see if this works
# in python v.3.8 the output of `csv.DictWriter` is a `dict`, but v3 prior to 3.8 it's `OrderedDict`
data = open_csv('credit_loan_dataset.csv')
test = dict(next(data))

# %%
test
# Out:
# {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#  'Transaction Report ID': '356191',
#  'Guarantee Country Name': 'Worldwide',
#  'Amount (USD)': '980144.4043',
#  'Currency Name': 'PERU - NUEVO SOL',
#  'Disbursement Date': '09/20/2011 12:00:00 AM',
#  'End Date': '09/09/2013 12:00:00 AM',
#  'Business Sector': '',
#  'City/Town': 'Cusco',
#  'State/Province/Region Name': 'Cusco',
#  'State/Province/Region Code': 'PE08',
#  'State/Province/Region Country Name': 'Peru',
#  'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#  'Is Woman Owned?': '0',
#  'Is First Time Borrower?': '1',
#  'Business Size': '>100',
#  'Latitude': '-13.518333',
#  'Longitude': '-71.978056'}

# %%
# again
test
# Out:
# {'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#  'Transaction Report ID': '356191',
#  'Guarantee Country Name': 'Worldwide',
#  'Amount (USD)': '980144.4043',
#  'Currency Name': 'PERU - NUEVO SOL',
#  'Disbursement Date': '09/20/2011 12:00:00 AM',
#  'End Date': '09/09/2013 12:00:00 AM',
#  'Business Sector': '',
#  'City/Town': 'Cusco',
#  'State/Province/Region Name': 'Cusco',
#  'State/Province/Region Code': 'PE08',
#  'State/Province/Region Country Name': 'Peru',
#  'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#  'Is Woman Owned?': '0',
#  'Is First Time Borrower?': '1',
#  'Business Size': '>100',
#  'Latitude': '-13.518333',
#  'Longitude': '-71.978056'}

# %%
# %lsmagic # this is a list of ipython features that you can use in Jupyter notebooks
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# some useful links for `%magic`:
#
# * https://ipython.readthedocs.io/en/stable/interactive/tutorial.html#magic-functions
# * https://stackoverflow.com/questions/49136737/how-profiling-class-method-using-ipython-lprun-magic-function

# %% [markdown]
# Profilers are important, but benchmarking is a dark art, it's easy to get misleading or "wrong" result. To install external profiler on conda/miniconda use `conda install line_profiler`, or follow guide in https://github.com/rkern/line_profiler#installation. memory_profiler is also available on conda & can be installed with `pip install memory_profiler`
#
# Make sure your in the right virtual env.

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
import json, csv
from pprint import pprint

def open_csv(filename, rows, dialect='excel'):
        
    with open(filename, 'r') as f:
        reader = csv.DictReader(f, dialect=dialect)
        for count in range(rows):
            yield next(reader)


def get_csv_rows(filename, row_count):
    # there's no need to convert to dict when using python 3.8+: return list(get_csv_rows(...))
    csv_rows = [dict(d) for d in list(open_csv(filename, row_count))]
    return csv_rows

# %%
data = get_csv_rows('credit_loan_dataset.csv', 20)

# %%
len(data)
# Out:
# 20

# %%
pprint({i: d['Transaction Report ID'] for i,d in enumerate(data)})
# Out:
# {0: '356191',
#  1: '331620',
#  2: '349835',
#  3: '385807',
#  4: '473058',
#  5: '420674',
#  6: '123514',
#  7: '369568',
#  8: '385756',
#  9: '420663',
#  10: '433368',
#  11: '435375',
#  12: '434741',
#  13: '434767',
#  14: '435376',
#  15: '439987',
#  16: '439991',
#  17: '439992',
#  18: '460017',
#  19: '460019'}

# %%
# %timeit get_csv_rows('credit_loan_dataset.csv', 20)
# Out:
# 201 µs ± 12.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %lprun get_csv_rows('credit_loan_dataset.csv', 20)

# %%
# %mprun -f get_csv_rows('credit_loan_dataset.csv', 20)
# Out:
# UsageError: Line magic function `%mprun` not found.

# %%
# %memit?
# Out:
# Object `%memit` not found.

# %%
# %%time
get_csv_rows('credit_loan_dataset.csv', 20)
# Out:
# CPU times: user 599 µs, sys: 546 µs, total: 1.15 ms
# Wall time: 727 µs
# [{'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Transaction Report ID': '331620',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1960288.809',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': 'Puno',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '-15',
#   'Longitude': '-70'},
#  {'Guarantee Number': '099-DCA-09-006C (ProEmpresa)',
#   'Transaction Report ID': '349835',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '2007490.637',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '01/18/2012 12:00:00 AM',
#   'End Date': '08/05/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Lima',
#   'State/Province/Region Name': 'Lima',
#   'State/Province/Region Code': 'PE15',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-12',
#   'Longitude': '-76.833333'},
#  {'Guarantee Number': '099-DCA-09-006D (Pro Mujer Peru)',
#   'Transaction Report ID': '385807',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1030888.031',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '04/11/2012 12:00:00 AM',
#   'End Date': '03/31/2015 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': '',
#   'State/Province/Region Code': '',
#   'State/Province/Region Country Name': '',
#   'Region Name': '',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '099-DCA-09-006F (COCLA)',
#   'Transaction Report ID': '473058',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1780000',
#   'Currency Name': 'UNITED STATES - DOLLAR',
#   'Disbursement Date': '08/15/2012 12:00:00 AM',
#   'End Date': '08/20/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006G (Manuela Ramos)',
#   'Transaction Report ID': '420674',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1158301.158',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '11/28/2012 12:00:00 AM',
#   'End Date': '11/28/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Lima',
#   'State/Province/Region Name': 'Lima',
#   'State/Province/Region Code': 'PE15',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '-12',
#   'Longitude': '-76.833333'},
#  {'Guarantee Number': '674A99DCA02',
#   'Transaction Report ID': '123514',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '22519059.31',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/09/2000 12:00:00 AM',
#   'End Date': '04/27/2011 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': '',
#   'State/Province/Region Name': '',
#   'State/Province/Region Code': '',
#   'State/Province/Region Country Name': '',
#   'Region Name': '',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '369568',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '54578.5324',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/31/2012 12:00:00 AM',
#   'End Date': '08/30/2017 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Potchefstroom',
#   'State/Province/Region Name': 'North-West',
#   'State/Province/Region Code': 'SF10',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '-26.716667',
#   'Longitude': '27.1'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '385756',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '83365.1784',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/28/2012 12:00:00 AM',
#   'End Date': '10/28/2017 12:00:00 AM',
#   'Business Sector': 'Manufacturing',
#   'City/Town': 'Port Elizaberth',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '420663',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '288738.5438',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '03/23/2013 12:00:00 AM',
#   'End Date': '04/23/2017 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '433368',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '89099.6499',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '06/11/2013 12:00:00 AM',
#   'End Date': '09/05/2018 12:00:00 AM',
#   'Business Sector': 'Agriculture',
#   'City/Town': 'Parys',
#   'State/Province/Region Name': 'Free State',
#   'State/Province/Region Code': 'SF03',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-26.903296',
#   'Longitude': '27.457268'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '435375',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '146061.6088',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/26/2013 12:00:00 AM',
#   'End Date': '08/26/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Sandton',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '-26.066788',
#   'Longitude': '28.046944'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '434741',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '287182.9082',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/01/2013 12:00:00 AM',
#   'End Date': '08/30/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '434767',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '71120.6606',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/01/2013 12:00:00 AM',
#   'End Date': '06/30/2019 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '435376',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '47235.0704',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/07/2013 12:00:00 AM',
#   'End Date': '08/31/2018 12:00:00 AM',
#   'Business Sector': 'Manufacturing',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '439987',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '94073.3772',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/14/2013 12:00:00 AM',
#   'End Date': '09/14/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Rivonia',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-26.053154',
#   'Longitude': '28.059594'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '439991',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '282220.1317',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/28/2013 12:00:00 AM',
#   'End Date': '09/28/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Sanbel',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '439992',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '157290.6867',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '12/20/2013 12:00:00 AM',
#   'End Date': '11/20/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Florida',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '460017',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '161603.0103',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/21/2014 12:00:00 AM',
#   'End Date': '02/28/2019 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Midrand',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-25.963611',
#   'Longitude': '28.137778'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '460019',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '43838.1938',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '03/07/2014 12:00:00 AM',
#   'End Date': '03/07/2019 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Midrand',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-25.963611',
#   'Longitude': '28.137778'}]

# %%
# %%time
get_csv_rows('credit_loan_dataset.csv', 500)
# Out:
# CPU times: user 5.07 ms, sys: 331 µs, total: 5.4 ms
# Wall time: 5.15 ms
# [{'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Transaction Report ID': '356191',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '980144.4043',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Transaction Report ID': '331620',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1960288.809',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': 'Puno',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '-15',
#   'Longitude': '-70'},
#  {'Guarantee Number': '099-DCA-09-006C (ProEmpresa)',
#   'Transaction Report ID': '349835',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '2007490.637',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '01/18/2012 12:00:00 AM',
#   'End Date': '08/05/2013 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Lima',
#   'State/Province/Region Name': 'Lima',
#   'State/Province/Region Code': 'PE15',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '>100',
#   'Latitude': '-12',
#   'Longitude': '-76.833333'},
#  {'Guarantee Number': '099-DCA-09-006D (Pro Mujer Peru)',
#   'Transaction Report ID': '385807',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1030888.031',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '04/11/2012 12:00:00 AM',
#   'End Date': '03/31/2015 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Puno',
#   'State/Province/Region Name': '',
#   'State/Province/Region Code': '',
#   'State/Province/Region Country Name': '',
#   'Region Name': '',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '>100',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '099-DCA-09-006F (COCLA)',
#   'Transaction Report ID': '473058',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1780000',
#   'Currency Name': 'UNITED STATES - DOLLAR',
#   'Disbursement Date': '08/15/2012 12:00:00 AM',
#   'End Date': '08/20/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Cusco',
#   'State/Province/Region Name': 'Cusco',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056'},
#  {'Guarantee Number': '099-DCA-09-006G (Manuela Ramos)',
#   'Transaction Report ID': '420674',
#   'Guarantee Country Name': 'Worldwide',
#   'Amount (USD)': '1158301.158',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '11/28/2012 12:00:00 AM',
#   'End Date': '11/28/2014 12:00:00 AM',
#   'Business Sector': '',
#   'City/Town': 'Lima',
#   'State/Province/Region Name': 'Lima',
#   'State/Province/Region Code': 'PE15',
#   'State/Province/Region Country Name': 'Peru',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '-12',
#   'Longitude': '-76.833333'},
#  {'Guarantee Number': '674A99DCA02',
#   'Transaction Report ID': '123514',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '22519059.31',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/09/2000 12:00:00 AM',
#   'End Date': '04/27/2011 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': '',
#   'State/Province/Region Name': '',
#   'State/Province/Region Code': '',
#   'State/Province/Region Country Name': '',
#   'Region Name': '',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '369568',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '54578.5324',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/31/2012 12:00:00 AM',
#   'End Date': '08/30/2017 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Potchefstroom',
#   'State/Province/Region Name': 'North-West',
#   'State/Province/Region Code': 'SF10',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '-26.716667',
#   'Longitude': '27.1'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '385756',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '83365.1784',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/28/2012 12:00:00 AM',
#   'End Date': '10/28/2017 12:00:00 AM',
#   'Business Sector': 'Manufacturing',
#   'City/Town': 'Port Elizaberth',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '420663',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '288738.5438',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '03/23/2013 12:00:00 AM',
#   'End Date': '04/23/2017 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '433368',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '89099.6499',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '06/11/2013 12:00:00 AM',
#   'End Date': '09/05/2018 12:00:00 AM',
#   'Business Sector': 'Agriculture',
#   'City/Town': 'Parys',
#   'State/Province/Region Name': 'Free State',
#   'State/Province/Region Code': 'SF03',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-26.903296',
#   'Longitude': '27.457268'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '435375',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '146061.6088',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/26/2013 12:00:00 AM',
#   'End Date': '08/26/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Sandton',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '-26.066788',
#   'Longitude': '28.046944'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '434741',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '287182.9082',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/01/2013 12:00:00 AM',
#   'End Date': '08/30/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '434767',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '71120.6606',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/01/2013 12:00:00 AM',
#   'End Date': '06/30/2019 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '435376',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '47235.0704',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/07/2013 12:00:00 AM',
#   'End Date': '08/31/2018 12:00:00 AM',
#   'Business Sector': 'Manufacturing',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '439987',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '94073.3772',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/14/2013 12:00:00 AM',
#   'End Date': '09/14/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Rivonia',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-26.053154',
#   'Longitude': '28.059594'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '439991',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '282220.1317',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/28/2013 12:00:00 AM',
#   'End Date': '09/28/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Sanbel',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '439992',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '157290.6867',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '12/20/2013 12:00:00 AM',
#   'End Date': '11/20/2018 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Florida',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '460017',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '161603.0103',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/21/2014 12:00:00 AM',
#   'End Date': '02/28/2019 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Midrand',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-25.963611',
#   'Longitude': '28.137778'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '460019',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '43838.1938',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '03/07/2014 12:00:00 AM',
#   'End Date': '03/07/2019 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Midrand',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-25.963611',
#   'Longitude': '28.137778'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '460018',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '112344.5826',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/04/2014 12:00:00 AM',
#   'End Date': '04/04/2019 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Germiston',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-26.234806',
#   'Longitude': '28.176654'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '473054',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '26642.984',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '05/30/2014 12:00:00 AM',
#   'End Date': '05/30/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Johannesburg',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-26.205171',
#   'Longitude': '28.049815'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '473052',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '8436.9449',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '06/24/2014 12:00:00 AM',
#   'End Date': '06/30/2019 12:00:00 AM',
#   'Business Sector': 'Education',
#   'City/Town': 'Johannesburg',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-26.205171',
#   'Longitude': '28.049815'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '473053',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '230017.762',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/05/2014 12:00:00 AM',
#   'End Date': '08/30/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Johannesburg',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-26.205171',
#   'Longitude': '28.049815'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500388',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '106478.8271',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/23/2014 12:00:00 AM',
#   'End Date': '10/23/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'George',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.963',
#   'Longitude': '22.461727'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500387',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '176679.5315',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/26/2014 12:00:00 AM',
#   'End Date': '10/26/2016 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '51--100',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500389',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '84773.5277',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/01/2014 12:00:00 AM',
#   'End Date': '11/01/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Randburg',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-26.099072',
#   'Longitude': '27.975854'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500399',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '109181.7512',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/14/2014 12:00:00 AM',
#   'End Date': '11/29/2019 12:00:00 AM',
#   'Business Sector': 'Transportation',
#   'City/Town': 'Bellville',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.900219',
#   'Longitude': '18.628468'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500394',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '24572.037',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/18/2014 12:00:00 AM',
#   'End Date': '11/30/2019 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Meyerton',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-26.559866',
#   'Longitude': '28.019501'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500392',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '50126.9555',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/25/2014 12:00:00 AM',
#   'End Date': '04/30/2019 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500393',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '106478.8271',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '12/08/2014 12:00:00 AM',
#   'End Date': '12/20/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500396',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '40953.395',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '12/11/2014 12:00:00 AM',
#   'End Date': '12/30/2019 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Somerset West',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-34.079375',
#   'Longitude': '18.85699'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500390',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '89933.6555',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '12/15/2014 12:00:00 AM',
#   'End Date': '12/15/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Centurion',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-25.840795',
#   'Longitude': '28.176102'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500383',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '155622.9011',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '12/30/2014 12:00:00 AM',
#   'End Date': '12/30/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '500395',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '22114.8333',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '01/12/2015 12:00:00 AM',
#   'End Date': '01/20/2020 12:00:00 AM',
#   'Business Sector': 'Education',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '501487',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '122860.1851',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '01/16/2015 12:00:00 AM',
#   'End Date': '12/15/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '506783',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '61020.5586',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/27/2015 12:00:00 AM',
#   'End Date': '03/01/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '501489',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '114669.5061',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '03/17/2015 12:00:00 AM',
#   'End Date': '09/15/2015 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Uitenhage',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-33.75757',
#   'Longitude': '25.397099'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '501745',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '162987.8861',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/01/2015 12:00:00 AM',
#   'End Date': '05/01/2020 12:00:00 AM',
#   'Business Sector': 'Transportation',
#   'City/Town': 'Limpopo',
#   'State/Province/Region Name': 'Limpopo',
#   'State/Province/Region Code': 'SF09',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '506707',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '141649.2014',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/14/2015 12:00:00 AM',
#   'End Date': '04/01/2020 12:00:00 AM',
#   'Business Sector': 'Manufacturing',
#   'City/Town': 'Pietermaritzburg',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-29.616785',
#   'Longitude': '30.39278'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '506709',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '136895.5698',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/17/2015 12:00:00 AM',
#   'End Date': '05/07/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Mellville',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '514607',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '90337.5009',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/22/2015 12:00:00 AM',
#   'End Date': '05/15/2020 12:00:00 AM',
#   'Business Sector': 'Transportation',
#   'City/Town': 'Vryheid',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-27.76952',
#   'Longitude': '30.791653'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '501488',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '36135.0004',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/30/2015 12:00:00 AM',
#   'End Date': '03/30/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Port Elizabeth',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-33.917988',
#   'Longitude': '25.570066'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '506708',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '32521.5003',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/30/2015 12:00:00 AM',
#   'End Date': '05/30/2019 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Port Elizabeth',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.917988',
#   'Longitude': '25.570066'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '501492',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '23126.4002',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '04/30/2015 12:00:00 AM',
#   'End Date': '03/30/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '501661',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '115632.0012',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '05/07/2015 12:00:00 AM',
#   'End Date': '04/07/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Gauteng',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '514612',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '205969.5021',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '06/26/2015 12:00:00 AM',
#   'End Date': '07/25/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '514610',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '43362.0004',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/06/2015 12:00:00 AM',
#   'End Date': '07/31/2020 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Jeffreys Bay',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '514611',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '46975.5005',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/06/2015 12:00:00 AM',
#   'End Date': '07/11/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Bellville',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.900219',
#   'Longitude': '18.628468'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '515813',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '325215.0033',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/22/2015 12:00:00 AM',
#   'End Date': '07/22/2020 12:00:00 AM',
#   'Business Sector': 'Manufacturing',
#   'City/Town': 'Johannesburg',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-26.205171',
#   'Longitude': '28.049815'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '515816',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '44971.3276',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/31/2015 12:00:00 AM',
#   'End Date': '07/31/2020 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Johannesburg',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-26.205171',
#   'Longitude': '28.049815'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '514613',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '180675.0018',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/05/2015 12:00:00 AM',
#   'End Date': '10/30/2019 12:00:00 AM',
#   'Business Sector': 'Information & Communication Technologies',
#   'City/Town': 'Pretoria',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-25.706944',
#   'Longitude': '28.229444'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '514609',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '34414.9743',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/05/2015 12:00:00 AM',
#   'End Date': '08/30/2018 12:00:00 AM',
#   'Business Sector': 'Agriculture',
#   'City/Town': 'Robertson',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-33.803418',
#   'Longitude': '19.885374'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '514608',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '23849.1002',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/11/2015 12:00:00 AM',
#   'End Date': '08/30/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Robertson',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-33.803418',
#   'Longitude': '19.885374'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '515814',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '18067.5002',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/31/2015 12:00:00 AM',
#   'End Date': '08/31/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Durban',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '519349',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '101916.0212',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '09/04/2015 12:00:00 AM',
#   'End Date': '10/01/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Bellville',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.900219',
#   'Longitude': '18.628468'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '525797',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '135888.0283',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/01/2015 12:00:00 AM',
#   'End Date': '09/20/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Eastern Cape',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '516209',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '50958.0106',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/02/2015 12:00:00 AM',
#   'End Date': '10/01/2020 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Fishhoek',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-34.155595',
#   'Longitude': '18.876779'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '515817',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '54355.2113',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/05/2015 12:00:00 AM',
#   'End Date': '10/05/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Rustenburg',
#   'State/Province/Region Name': 'North-West',
#   'State/Province/Region Code': 'SF10',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-25.667562',
#   'Longitude': '27.242079'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '515815',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '99130.3166',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/09/2015 12:00:00 AM',
#   'End Date': '10/09/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Claremont',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '516208',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '23780.4049',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/09/2015 12:00:00 AM',
#   'End Date': '10/09/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Helderberg',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-34.030479',
#   'Longitude': '18.831133'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '516210',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '186846.0389',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/13/2015 12:00:00 AM',
#   'End Date': '10/01/2020 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '516211',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '193640.4403',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/23/2015 12:00:00 AM',
#   'End Date': '10/01/2020 12:00:00 AM',
#   'Business Sector': 'Agriculture',
#   'City/Town': 'Newtondale',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-33.342195',
#   'Longitude': '27.067087'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524913',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '203832.0424',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/11/2015 12:00:00 AM',
#   'End Date': '11/11/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '51--100',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524914',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '48666.259',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/15/2015 12:00:00 AM',
#   'End Date': '11/15/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Midrand',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '1--5',
#   'Latitude': '-25.963611',
#   'Longitude': '28.137778'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524920',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '154232.9121',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '01/22/2016 12:00:00 AM',
#   'End Date': '01/22/2021 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524923',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '165366.84',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '01/29/2016 12:00:00 AM',
#   'End Date': '01/29/2021 12:00:00 AM',
#   'Business Sector': 'Trade/Commerce',
#   'City/Town': 'Eastern Cape',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524916',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '66449.2458',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/02/2016 12:00:00 AM',
#   'End Date': '02/02/2021 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Eastern cape',
#   'State/Province/Region Name': 'Eastern Cape',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524917',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '122299.2254',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/04/2016 12:00:00 AM',
#   'End Date': '02/04/2021 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Alberton Gauteng',
#   'State/Province/Region Name': 'Gauteng',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '',
#   'Longitude': ''},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524924',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '13588.8028',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/09/2016 12:00:00 AM',
#   'End Date': '02/09/2021 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524915',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '48240.25',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/12/2016 12:00:00 AM',
#   'End Date': '02/12/2021 12:00:00 AM',
#   'Business Sector': 'Transportation',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': '6--10',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524936',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '114759.1385',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/24/2016 12:00:00 AM',
#   'End Date': '02/24/2020 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Cape Town',
#   'State/Province/Region Name': 'Western Cape',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': '11--50',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218'},
#  {'Guarantee Number': '674-DCA-11-016',
#   'Transaction Report ID': '524941',
#   'Guarantee Country Name': 'South Africa',
#   'Amount (USD)': '611496.1272',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/24/2016 12:00:00 AM',
#   'End Date': '03/01/2017 12:00:00 AM',
#   'Business Sector': 'Other Service',
#   'City/Town': 'Gauteng',
#   'State/Province/Region Name': 'Gauteng',
# ...
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369099',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '634.3165',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '11/29/2011 12:00:00 AM',
#   'End Date': '05/29/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368974',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '634.3165',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '11/29/2011 12:00:00 AM',
#   'End Date': '05/29/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369100',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '11/29/2011 12:00:00 AM',
#   'End Date': '04/29/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368975',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '11/29/2011 12:00:00 AM',
#   'End Date': '04/29/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369101',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1268.633',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/05/2011 12:00:00 AM',
#   'End Date': '06/05/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368976',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1268.633',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/05/2011 12:00:00 AM',
#   'End Date': '06/05/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369102',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/08/2011 12:00:00 AM',
#   'End Date': '06/08/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368977',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/08/2011 12:00:00 AM',
#   'End Date': '06/08/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369103',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '634.3165',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/09/2011 12:00:00 AM',
#   'End Date': '06/09/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368978',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '634.3165',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/09/2011 12:00:00 AM',
#   'End Date': '06/09/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369104',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/09/2011 12:00:00 AM',
#   'End Date': '05/09/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368979',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/09/2011 12:00:00 AM',
#   'End Date': '05/09/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369105',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '951.4748',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/12/2011 12:00:00 AM',
#   'End Date': '06/12/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368980',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '951.4748',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/12/2011 12:00:00 AM',
#   'End Date': '06/12/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '1',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368981',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1649.223',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '07/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369106',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1649.223',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '07/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '1',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368982',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '2854.4244',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '06/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369107',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '2854.4244',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '06/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368983',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '08/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369108',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '08/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368984',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '06/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369109',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '1902.9496',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/13/2011 12:00:00 AM',
#   'End Date': '06/13/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368985',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '2473.8344',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/15/2011 12:00:00 AM',
#   'End Date': '07/15/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '369110',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '2473.8344',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/15/2011 12:00:00 AM',
#   'End Date': '07/15/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'},
#  {'Guarantee Number': '620-DCA-10-004',
#   'Transaction Report ID': '368986',
#   'Guarantee Country Name': 'Nigeria',
#   'Amount (USD)': '951.4748',
#   'Currency Name': 'NIGERIA - NAIRA',
#   'Disbursement Date': '12/15/2011 12:00:00 AM',
#   'End Date': '06/15/2012 12:00:00 AM',
#   'Business Sector': 'Health',
#   'City/Town': 'Lagos',
#   'State/Province/Region Name': 'Lagos',
#   'State/Province/Region Code': 'NI05',
#   'State/Province/Region Country Name': 'Nigeria',
#   'Region Name': 'AFRICA',
#   'Is Woman Owned?': '0',
#   'Is First Time Borrower?': '0',
#   'Business Size': 'N/A',
#   'Latitude': '6.453056',
#   'Longitude': '3.395833'}]

# %%
# !python -m cProfile -s cumtime chunk_csv.py
# Out:
# [{'Amount (USD)': '980144.4043',
#   'Business Sector': '',
#   'Business Size': '>100',
#   'City/Town': 'Cusco',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/09/2013 12:00:00 AM',
#   'Guarantee Country Name': 'Worldwide',
#   'Guarantee Number': '099-DCA-09-006A (Asociacion Arariwa)',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'State/Province/Region Name': 'Cusco',
#   'Transaction Report ID': '356191'},
#  {'Amount (USD)': '1960288.809',
#   'Business Sector': '',
#   'Business Size': '>100',
#   'City/Town': 'Puno',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '09/20/2011 12:00:00 AM',
#   'End Date': '09/04/2014 12:00:00 AM',
#   'Guarantee Country Name': 'Worldwide',
#   'Guarantee Number': '099-DCA-09-006B (Pro Mujer Peru)',
#   'Is First Time Borrower?': '0',
#   'Is Woman Owned?': '0',
#   'Latitude': '-15',
#   'Longitude': '-70',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'State/Province/Region Code': 'PE21',
#   'State/Province/Region Country Name': 'Peru',
#   'State/Province/Region Name': 'Puno',
#   'Transaction Report ID': '331620'},
#  {'Amount (USD)': '2007490.637',
#   'Business Sector': '',
#   'Business Size': '>100',
#   'City/Town': 'Lima',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '01/18/2012 12:00:00 AM',
#   'End Date': '08/05/2013 12:00:00 AM',
#   'Guarantee Country Name': 'Worldwide',
#   'Guarantee Number': '099-DCA-09-006C (ProEmpresa)',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '-12',
#   'Longitude': '-76.833333',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'State/Province/Region Code': 'PE15',
#   'State/Province/Region Country Name': 'Peru',
#   'State/Province/Region Name': 'Lima',
#   'Transaction Report ID': '349835'},
#  {'Amount (USD)': '1030888.031',
#   'Business Sector': '',
#   'Business Size': '>100',
#   'City/Town': 'Puno',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '04/11/2012 12:00:00 AM',
#   'End Date': '03/31/2015 12:00:00 AM',
#   'Guarantee Country Name': 'Worldwide',
#   'Guarantee Number': '099-DCA-09-006D (Pro Mujer Peru)',
#   'Is First Time Borrower?': '0',
#   'Is Woman Owned?': '0',
#   'Latitude': '',
#   'Longitude': '',
#   'Region Name': '',
#   'State/Province/Region Code': '',
#   'State/Province/Region Country Name': '',
#   'State/Province/Region Name': '',
#   'Transaction Report ID': '385807'},
#  {'Amount (USD)': '1780000',
#   'Business Sector': '',
#   'Business Size': 'N/A',
#   'City/Town': 'Cusco',
#   'Currency Name': 'UNITED STATES - DOLLAR',
#   'Disbursement Date': '08/15/2012 12:00:00 AM',
#   'End Date': '08/20/2014 12:00:00 AM',
#   'Guarantee Country Name': 'Worldwide',
#   'Guarantee Number': '099-DCA-09-006F (COCLA)',
#   'Is First Time Borrower?': '0',
#   'Is Woman Owned?': '0',
#   'Latitude': '-13.518333',
#   'Longitude': '-71.978056',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'State/Province/Region Code': 'PE08',
#   'State/Province/Region Country Name': 'Peru',
#   'State/Province/Region Name': 'Cusco',
#   'Transaction Report ID': '473058'},
#  {'Amount (USD)': '1158301.158',
#   'Business Sector': '',
#   'Business Size': 'N/A',
#   'City/Town': 'Lima',
#   'Currency Name': 'PERU - NUEVO SOL',
#   'Disbursement Date': '11/28/2012 12:00:00 AM',
#   'End Date': '11/28/2014 12:00:00 AM',
#   'Guarantee Country Name': 'Worldwide',
#   'Guarantee Number': '099-DCA-09-006G (Manuela Ramos)',
#   'Is First Time Borrower?': '0',
#   'Is Woman Owned?': '0',
#   'Latitude': '-12',
#   'Longitude': '-76.833333',
#   'Region Name': 'LATIN AMERICA & THE CARIBBEAN',
#   'State/Province/Region Code': 'PE15',
#   'State/Province/Region Country Name': 'Peru',
#   'State/Province/Region Name': 'Lima',
#   'Transaction Report ID': '420674'},
#  {'Amount (USD)': '22519059.31',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': '',
#   'City/Town': '',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '11/09/2000 12:00:00 AM',
#   'End Date': '04/27/2011 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674A99DCA02',
#   'Is First Time Borrower?': '0',
#   'Is Woman Owned?': '0',
#   'Latitude': '',
#   'Longitude': '',
#   'Region Name': '',
#   'State/Province/Region Code': '',
#   'State/Province/Region Country Name': '',
#   'State/Province/Region Name': '',
#   'Transaction Report ID': '123514'},
#  {'Amount (USD)': '54578.5324',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': 'N/A',
#   'City/Town': 'Potchefstroom',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/31/2012 12:00:00 AM',
#   'End Date': '08/30/2017 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '0',
#   'Is Woman Owned?': '0',
#   'Latitude': '-26.716667',
#   'Longitude': '27.1',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF10',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'North-West',
#   'Transaction Report ID': '369568'},
#  {'Amount (USD)': '83365.1784',
#   'Business Sector': 'Manufacturing',
#   'Business Size': '11--50',
#   'City/Town': 'Port Elizaberth',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/28/2012 12:00:00 AM',
#   'End Date': '10/28/2017 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '',
#   'Longitude': '',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF05',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Eastern Cape',
#   'Transaction Report ID': '385756'},
#  {'Amount (USD)': '288738.5438',
#   'Business Sector': 'Other Service',
#   'Business Size': '11--50',
#   'City/Town': 'Durban',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '03/23/2013 12:00:00 AM',
#   'End Date': '04/23/2017 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '1',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'Transaction Report ID': '420663'},
#  {'Amount (USD)': '89099.6499',
#   'Business Sector': 'Agriculture',
#   'Business Size': '11--50',
#   'City/Town': 'Parys',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '06/11/2013 12:00:00 AM',
#   'End Date': '09/05/2018 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '-26.903296',
#   'Longitude': '27.457268',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF03',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Free State',
#   'Transaction Report ID': '433368'},
#  {'Amount (USD)': '146061.6088',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': 'N/A',
#   'City/Town': 'Sandton',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '07/26/2013 12:00:00 AM',
#   'End Date': '08/26/2018 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '-26.066788',
#   'Longitude': '28.046944',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Gauteng',
#   'Transaction Report ID': '435375'},
#  {'Amount (USD)': '287182.9082',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': '11--50',
#   'City/Town': 'Durban',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/01/2013 12:00:00 AM',
#   'End Date': '08/30/2018 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'Transaction Report ID': '434741'},
#  {'Amount (USD)': '71120.6606',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': '1--5',
#   'City/Town': 'Durban',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/01/2013 12:00:00 AM',
#   'End Date': '06/30/2019 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '1',
#   'Latitude': '-29.857896',
#   'Longitude': '31.029198',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF02',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'KwaZulu-Natal',
#   'Transaction Report ID': '434767'},
#  {'Amount (USD)': '47235.0704',
#   'Business Sector': 'Manufacturing',
#   'Business Size': '11--50',
#   'City/Town': 'Cape Town',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '08/07/2013 12:00:00 AM',
#   'End Date': '08/31/2018 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '-33.925839',
#   'Longitude': '18.423218',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Western Cape',
#   'Transaction Report ID': '435376'},
#  {'Amount (USD)': '94073.3772',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': '1--5',
#   'City/Town': 'Rivonia',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/14/2013 12:00:00 AM',
#   'End Date': '09/14/2018 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '-26.053154',
#   'Longitude': '28.059594',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Gauteng',
#   'Transaction Report ID': '439987'},
#  {'Amount (USD)': '282220.1317',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': '11--50',
#   'City/Town': 'Sanbel',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '10/28/2013 12:00:00 AM',
#   'End Date': '09/28/2018 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '0',
#   'Latitude': '',
#   'Longitude': '',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF11',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Western Cape',
#   'Transaction Report ID': '439991'},
#  {'Amount (USD)': '157290.6867',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': '11--50',
#   'City/Town': 'Florida',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '12/20/2013 12:00:00 AM',
#   'End Date': '11/20/2018 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '0',
#   'Is Woman Owned?': '0',
#   'Latitude': '',
#   'Longitude': '',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Gauteng',
#   'Transaction Report ID': '439992'},
#  {'Amount (USD)': '161603.0103',
#   'Business Sector': 'Health',
#   'Business Size': '1--5',
#   'City/Town': 'Midrand',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '02/21/2014 12:00:00 AM',
#   'End Date': '02/28/2019 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '1',
#   'Latitude': '-25.963611',
#   'Longitude': '28.137778',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Gauteng',
#   'Transaction Report ID': '460017'},
#  {'Amount (USD)': '43838.1938',
#   'Business Sector': 'Trade/Commerce',
#   'Business Size': '1--5',
#   'City/Town': 'Midrand',
#   'Currency Name': 'SOUTH AFRICA - RAND',
#   'Disbursement Date': '03/07/2014 12:00:00 AM',
#   'End Date': '03/07/2019 12:00:00 AM',
#   'Guarantee Country Name': 'South Africa',
#   'Guarantee Number': '674-DCA-11-016',
#   'Is First Time Borrower?': '1',
#   'Is Woman Owned?': '1',
#   'Latitude': '-25.963611',
#   'Longitude': '28.137778',
#   'Region Name': 'AFRICA',
#   'State/Province/Region Code': 'SF06',
#   'State/Province/Region Country Name': 'South Africa',
#   'State/Province/Region Name': 'Gauteng',
#   'Transaction Report ID': '460019'}]
#          21427 function calls (19447 primitive calls) in 0.016 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       8/1    0.000    0.000    0.016    0.016 {built-in method builtins.exec}
#         1    0.000    0.000    0.016    0.016 chunk_csv.py:1(<module>)
#         1    0.000    0.000    0.009    0.009 pprint.py:47(pprint)
#         1    0.000    0.000    0.009    0.009 pprint.py:138(pprint)
#     381/1    0.000    0.000    0.009    0.009 pprint.py:154(_format)
#         1    0.000    0.000    0.008    0.008 pprint.py:207(_pprint_list)
#         1    0.000    0.000    0.008    0.008 pprint.py:350(_format_items)
#       9/4    0.000    0.000    0.006    0.002 <frozen importlib._bootstrap>:978(_find_and_load)
#       9/4    0.000    0.000    0.006    0.002 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#        20    0.000    0.000    0.006    0.000 pprint.py:180(_pprint_dict)
#       9/4    0.000    0.000    0.006    0.001 <frozen importlib._bootstrap>:663(_load_unlocked)
#       7/4    0.000    0.000    0.005    0.001 <frozen importlib._bootstrap_external>:722(exec_module)
#        20    0.001    0.000    0.005    0.000 pprint.py:333(_format_dict_items)
#       741    0.001    0.000    0.005    0.000 pprint.py:391(_repr)
#      12/4    0.000    0.000    0.004    0.001 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#       741    0.000    0.000    0.004    0.000 pprint.py:400(format)
#  2201/741    0.002    0.000    0.004    0.000 pprint.py:490(_safe_repr)
#         1    0.000    0.000    0.003    0.003 __init__.py:97(<module>)
#        60    0.001    0.000    0.003    0.000 {built-in method builtins.sorted}
#      1483    0.002    0.000    0.002    0.000 {method 'write' of '_io.TextIOWrapper' objects}
#         7    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:793(get_code)
#         1    0.000    0.000    0.002    0.002 decoder.py:2(<module>)
#         9    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#         6    0.000    0.000    0.001    0.000 re.py:232(compile)
#         6    0.000    0.000    0.001    0.000 re.py:271(_compile)
#     14/13    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.__import__}
#         9    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#         9    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#         6    0.000    0.000    0.001    0.000 sre_compile.py:759(compile)
#         1    0.000    0.000    0.001    0.001 csv.py:4(<module>)
#         1    0.000    0.000    0.001    0.001 scanner.py:2(<module>)
#         9    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:576(module_from_spec)
#         7    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:523(_compile_bytecode)
#      1080    0.001    0.000    0.001    0.000 pprint.py:94(_safe_tuple)
#         7    0.001    0.000    0.001    0.000 {built-in method marshal.loads}
#        23    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#         1    0.000    0.000    0.001    0.001 encoder.py:2(<module>)
#         6    0.000    0.000    0.001    0.000 sre_parse.py:913(parse)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1040(create_module)
#         2    0.001    0.000    0.001    0.000 {built-in method _imp.create_dynamic}
#         1    0.000    0.000    0.001    0.001 chunk_csv.py:20(get_csv_rows)
#      13/6    0.000    0.000    0.001    0.000 sre_parse.py:411(_parse_sub)
#        21    0.000    0.000    0.001    0.000 chunk_csv.py:4(open_csv)
#      15/6    0.000    0.000    0.001    0.000 sre_parse.py:469(_parse)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:914(get_data)
#      3240    0.000    0.000    0.000    0.000 pprint.py:87(__lt__)
#        43    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#         6    0.000    0.000    0.000    0.000 sre_compile.py:598(_code)
#        43    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#      2160    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#      25/6    0.000    0.000    0.000    0.000 sre_compile.py:71(_compile)
#        29    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#      2160    0.000    0.000    0.000    0.000 pprint.py:84(__init__)
#     62/41    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#       115    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#        20    0.000    0.000    0.000    0.000 csv.py:108(__next__)
#        12    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:93(_path_isfile)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:84(_path_is_mode_type)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
# 1143/1115    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:951(path_stats)
#        14    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:271(cache_from_source)
#        14    0.000    0.000    0.000    0.000 sre_compile.py:276(_optimize_charset)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:318(__exit__)
#         6    0.000    0.000    0.000    0.000 sre_compile.py:536(_compile_info)
#       741    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#        16    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:403(cached)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:369(_get_cached)
#        20    0.000    0.000    0.000    0.000 enum.py:284(__call__)
#       123    0.000    0.000    0.000    0.000 sre_parse.py:164(__getitem__)
#      1052    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 enum.py:830(__or__)
#         7    0.000    0.000    0.000    0.000 {method 'read' of '_io.FileIO' objects}
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       115    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#        20    0.000    0.000    0.000    0.000 enum.py:526(__new__)
#        95    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#     31/12    0.000    0.000    0.000    0.000 sre_parse.py:174(getwidth)
#       170    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 enum.py:793(_missing_)
#         2    0.000    0.000    0.000    0.000 enum.py:800(_create_pseudo_member_)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1351(_get_spec)
#         1    0.000    0.000    0.000    0.000 pprint.py:35(<module>)
#       422    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         2    0.000    0.000    0.000    0.000 enum.py:872(_decompose)
#        33    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 sre_parse.py:96(closegroup)
#       102    0.000    0.000    0.000    0.000 sre_parse.py:233(__next)
#        71    0.000    0.000    0.000    0.000 sre_parse.py:254(get)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:438(_classify_pyc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1404(_fill_cache)
#        41    0.000    0.000    0.000    0.000 csv.py:94(fieldnames)
#       123    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#       211    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 chunk_csv.py:28(<listcomp>)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:574(spec_from_file_location)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.listdir}
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:103(release)
#         6    0.000    0.000    0.000    0.000 enum.py:836(__and__)
#         2    0.000    0.000    0.000    0.000 enum.py:890(<listcomp>)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         6    0.000    0.000    0.000    0.000 sre_parse.py:224(__init__)
#        16    0.000    0.000    0.000    0.000 sre_parse.py:295(_class_escape)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:78(acquire)
#         4    0.000    0.000    0.000    0.000 sre_compile.py:411(_mk_bitmap)
#       244    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        71    0.000    0.000    0.000    0.000 sre_parse.py:249(match)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1190(_path_hooks)
#        27    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:859(__exit__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#        14    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:62(_path_split)
#        14    0.000    0.000    0.000    0.000 sre_compile.py:249(_compile_charset)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#       8/5    0.000    0.000    0.000    0.000 sre_compile.py:461(_get_literal_prefix)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:471(_validate_timestamp_pyc)
#         9    0.000    0.000    0.000    0.000 sre_compile.py:423(_simple)
#         1    0.000    0.000    0.000    0.000 pprint.py:98(PrettyPrinter)
#         3    0.000    0.000    0.000    0.000 {built-in method _csv.register_dialect}
#        67    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        71    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1445(path_hook_for_FileFinder)
#        52    0.000    0.000    0.000    0.000 sre_parse.py:160(__len__)
#        59    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         9    0.000    0.000    0.000    0.000 sre_parse.py:408(_uniq)
#        28    0.000    0.000    0.000    0.000 types.py:164(__get__)
#        38    0.000    0.000    0.000    0.000 sre_parse.py:286(tell)
#        21    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:51(_r_long)
#         4    0.000    0.000    0.000    0.000 sre_compile.py:413(<listcomp>)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:84(opengroup)
#        26    0.000    0.000    0.000    0.000 sre_parse.py:111(__init__)
#         7    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:194(_lock_unlock_module)
#        25    0.000    0.000    0.000    0.000 sre_parse.py:172(append)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#         5    0.000    0.000    0.000    0.000 sre_compile.py:492(_get_charset_prefix)
#         1    0.000    0.000    0.000    0.000 decoder.py:284(__init__)
#        68    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        48    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#        47    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 codecs.py:319(decode)
#         6    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#        23    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:401(_check_name_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1319(__init__)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:258(getwhile)
#        47    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        22    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#        27    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#        12    0.000    0.000    0.000    0.000 sre_compile.py:595(isstring)
#        24    0.000    0.000    0.000    0.000 sre_parse.py:81(groups)
#         1    0.000    0.000    0.000    0.000 csv.py:81(DictReader)
#        11    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#        36    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1048(exec_module)
#        12    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        34    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:98(_path_isdir)
#         5    0.000    0.000    0.000    0.000 enum.py:907(_power_of_two)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:76(__init__)
#         4    0.000    0.000    0.000    0.000 sre_parse.py:343(_escape)
#         1    0.000    0.000    0.000    0.000 encoder.py:104(__init__)
#        21    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         9    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#        23    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        18    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        12    0.000    0.000    0.000    0.000 sre_compile.py:65(_combine_flags)
#         6    0.000    0.000    0.000    0.000 sre_parse.py:897(fix_flags)
#         1    0.000    0.000    0.000    0.000 csv.py:82(__init__)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:5(<module>)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:884(__init__)
#         1    0.000    0.000    0.000    0.000 decoder.py:254(JSONDecoder)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#        17    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:719(create_module)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1433(<setcomp>)
#        23    0.000    0.000    0.000    0.000 enum.py:623(name)
#        10    0.000    0.000    0.000    0.000 sre_parse.py:168(__setitem__)
#         1    0.000    0.000    0.000    0.000 pprint.py:99(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        43    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:909(get_filename)
#         1    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#         3    0.000    0.000    0.000    0.000 enum.py:855(_high_bit)
#        13    0.000    0.000    0.000    0.000 sre_compile.py:453(_get_iscased)
#         1    0.000    0.000    0.000    0.000 encoder.py:73(JSONEncoder)
#         1    0.000    0.000    0.000    0.000 csv.py:24(Dialect)
#         1    0.000    0.000    0.000    0.000 {built-in method _csv.reader}
#         1    0.000    0.000    0.000    0.000 {method 'setter' of 'property' objects}
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1008f0568}
#         6    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 {built-in method _imp.exec_dynamic}
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1029(__init__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1325(<genexpr>)
#         5    0.000    0.000    0.000    0.000 enum.py:628(value)
#         5    0.000    0.000    0.000    0.000 enum.py:901(<lambda>)
#         1    0.000    0.000    0.000    0.000 decoder.py:20(JSONDecodeError)
#         1    0.000    0.000    0.000    0.000 csv.py:55(excel)
#         1    0.000    0.000    0.000    0.000 csv.py:70(unix_dialect)
#         1    0.000    0.000    0.000    0.000 csv.py:131(DictWriter)
#         1    0.000    0.000    0.000    0.000 csv.py:166(Sniffer)
#         1    0.000    0.000    0.000    0.000 pprint.py:72(_safe_key)
#         3    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 csv.py:65(excel_tab)
